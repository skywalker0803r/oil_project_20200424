# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import joblib

# %%
from API.utils import *

# %%
eva = EVA()

# %%
import_naphtha_11_dict = dict({
    'T10': 62,
    'T50': 98.5,
    'T90': 142.1,
    'N+A': 39.4,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 30,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 2.5,
})

# %%
import_naphtha_12_dict = dict({
    'T10': 62,
    'T50': 98.5,
    'T90': 142.1,
    'N+A': 39.4,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1.5,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 20,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 5,
})

# %%
import_naphtha_13_dict = dict({
    'T10': 62,
    'T50': 98.5,
    'T90': 142.1,
    'N+A': 39.4,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 2,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 10,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 10,
})

# %%
import_naphtha_21_dict = dict({
    'T10': 65.9,
    'T50': 97.8,
    'T90': 137.3,
    'N+A': 35.9,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 30,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 2.5,
})

# %%
import_naphtha_22_dict = dict({
    'T10': 65.9,
    'T50': 97.8,
    'T90': 137.3,
    'N+A': 35.9,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1.5,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 20,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 5,
})

# %%
import_naphtha_23_dict = dict({
    'T10': 65.9,
    'T50': 97.8,
    'T90': 137.3,
    'N+A': 35.9,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 2,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 10,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 10,
})

# %%
import_naphtha_31_dict = dict({
    'T10': 102,
    'T50': 114.6,
    'T90': 136.8,
    'N+A': 49.3,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 30,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 2.5,
})

# %%
import_naphtha_32_dict = dict({
    'T10': 102,
    'T50': 114.6,
    'T90': 136.8,
    'N+A': 49.3,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1.5,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 20,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 5,
})

# %%
import_naphtha_33_dict = dict({
    'T10': 102,
    'T50': 114.6,
    'T90': 136.8,
    'N+A': 49.3,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 2,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 10,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 10,
})

# %%
import_naphtha_41_dict = dict({
    'T10': 93.3,
    'T50': 112.9,
    'T90': 140.2,
    'N+A': 58.7,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 30,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 2.5,
})

# %%
import_naphtha_42_dict = dict({
    'T10': 93.3,
    'T50': 112.9,
    'T90': 140.2,
    'N+A': 58.7,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1.5,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 20,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 5,
})

# %%
import_naphtha_43_dict = dict({
    'T10': 93.3,
    'T50': 112.9,
    'T90': 140.2,
    'N+A': 58.7,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 2,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 10,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 1,
})

# %%
import_naphtha_51_dict = dict({
    'T10': 96.5,
    'T50': 116,
    'T90': 142,
    'N+A': 55,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 30,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 2.5,
})

# %%
import_naphtha_52_dict = dict({
    'T10': 96.5,
    'T50': 116,
    'T90': 142,
    'N+A': 55,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1.5,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 20,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 5,
})

# %%
import_naphtha_53_dict = dict({
    'T10': 96.5,
    'T50': 116,
    'T90': 142,
    'N+A': 55,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 2,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 10,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 10,
})

# %%
import_naphtha_61_dict = dict({
    'T10': 96.6,
    'T50': 116.3,
    'T90': 143.5,
    'N+A': 52.5,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 30,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 2.5,
})

# %%
import_naphtha_62_dict = dict({
    'T10': 96.6,
    'T50': 116.3,
    'T90': 143.5,
    'N+A': 52.5,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 1.5,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 20,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 5,
})

# %%
import_naphtha_63_dict = dict({
    'T10': 96.6,
    'T50': 116.3,
    'T90': 143.5,
    'N+A': 52.5,
    'Case Conditions_C6P- in Heart Cut (Input)_wt%': 2,
    'Case Conditions_Feed Rate to C013 (Input)_m3/hr': 10,
    'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr': 100,
    'Case Conditions_C7+ in Light End (Input)_wt%': 10,
})

# %%
col = ['T10', 'T50', 'T90', 'N+A',
   'Case Conditions_Feed Rate to C013 (Input)_m3/hr',
   'Case Conditions_C7+ in Light End (Input)_wt%',
   'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr',
   'Case Conditions_C6P- in Heart Cut (Input)_wt%']
x = pd.DataFrame(import_naphtha_63_dict,index=[0])[col]
eva(x)

# %%
def Naphtha_condition_to_reformer_input(import_naphtha_input:dict):
    
    # 欄位要按照以下順序擺放
    col = ['T10', 'T50', 'T90', 'N+A',
       'Case Conditions_Feed Rate to C013 (Input)_m3/hr',
       'Case Conditions_C7+ in Light End (Input)_wt%',
       'Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr',
       'Case Conditions_C6P- in Heart Cut (Input)_wt%']
    x = pd.DataFrame(import_naphtha_input,index=[0])[col]
    
    # 後面都一樣
    eva(x)
    reformer_input = eva.reformer_input#.to_dict()
    #for i, j in reformer_input.items():
    #    reformer_input.update({i:j[0]})
    #reformer_input_df = pd.DataFrame(reformer_input,index = [0])
    return reformer_input

# %%
reformer_input_11 = Naphtha_condition_to_reformer_input(import_naphtha_11_dict)
reformer_input_12 = Naphtha_condition_to_reformer_input(import_naphtha_12_dict)
reformer_input_13 = Naphtha_condition_to_reformer_input(import_naphtha_13_dict)
reformer_input_21 = Naphtha_condition_to_reformer_input(import_naphtha_21_dict)
reformer_input_22 = Naphtha_condition_to_reformer_input(import_naphtha_22_dict)
reformer_input_23 = Naphtha_condition_to_reformer_input(import_naphtha_23_dict)
reformer_input_31 = Naphtha_condition_to_reformer_input(import_naphtha_31_dict)
reformer_input_32 = Naphtha_condition_to_reformer_input(import_naphtha_32_dict)
reformer_input_33 = Naphtha_condition_to_reformer_input(import_naphtha_33_dict)
reformer_input_41 = Naphtha_condition_to_reformer_input(import_naphtha_41_dict)
reformer_input_42 = Naphtha_condition_to_reformer_input(import_naphtha_42_dict)
reformer_input_43 = Naphtha_condition_to_reformer_input(import_naphtha_43_dict)
reformer_input_51 = Naphtha_condition_to_reformer_input(import_naphtha_51_dict)
reformer_input_52 = Naphtha_condition_to_reformer_input(import_naphtha_52_dict)
reformer_input_53 = Naphtha_condition_to_reformer_input(import_naphtha_53_dict)
reformer_input_61 = Naphtha_condition_to_reformer_input(import_naphtha_61_dict)
reformer_input_62 = Naphtha_condition_to_reformer_input(import_naphtha_62_dict)
reformer_input_63 = Naphtha_condition_to_reformer_input(import_naphtha_63_dict)

# %%
df = pd.concat([reformer_input_11,
           reformer_input_12,
           reformer_input_13,
           reformer_input_21,
           reformer_input_22,
           reformer_input_23,
           reformer_input_31,
           reformer_input_32,
           reformer_input_33,
           reformer_input_41,
           reformer_input_42,
           reformer_input_43,
           reformer_input_51,
           reformer_input_52,
           reformer_input_53,
           reformer_input_61,
           reformer_input_62,
           reformer_input_63,
          ])

# %%
df.head()
# Out:
#        N+2A in Naphtha Feed, wt%      Chlorine in Fresh Catalyst, wt%  \
# 0                      65.871112                                0.942
# 0                      66.809044                                0.942
# 0                      67.751586                                0.942
# 0                      58.140342                                0.942
# 0                      59.059323                                0.942
#
#    Carbon in Spent Catalyst, %      C6P- in Naphtha Feed, wt%  \
# 0                         3.78                            1.0
# 0                         3.78                            1.5
# 0                         3.78                            2.0
# 0                         3.78                            1.0
# 0                         3.78                            1.5
#
#        3R211 Inlet Tem, oC      3R212 Inlet Temp, oC  \
# 0                    517.0                     517.0
# 0                    517.0                     517.0
# ...

# %%
df.to_csv('./reformer_input of import naphtha.csv',index = False)
