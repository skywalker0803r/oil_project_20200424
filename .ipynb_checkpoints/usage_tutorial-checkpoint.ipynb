# %%
from API.utils import EVA
from API.utils import *
import joblib
from tqdm import tqdm_notebook as tqdm

# %%
col_names = joblib.load('./data/phase_2/cleaned/col_names.pkl')
eva = EVA()

# %% [markdown]
# ## 準備輸入資料

# %%
x4 = pd.read_csv('./data/phase_1/test_170.csv',index_col=0).sample(30)[['T10','T50','T90','N+A']].reset_index(drop=True)

# %%
case4 = pd.read_csv('./data/phase_2/cleaned/train.csv',index_col=0)[col_names['case']].sample(30).reset_index(drop=True)

# %%
Input = x4.join(case4)
Input
# Out:
#       T10    T50    T90     N+A  \
# 0    94.0  112.7  141.2  47.873
# 1    89.9  112.1  145.4  46.988
# 2   105.6  122.6  146.7  32.547
# 3   104.5  120.9  145.6  32.249
# 4    96.9  117.0  144.2  53.266
# 5    99.6  119.9  145.5  38.952
# 6    96.1  115.9  142.1  52.450
# 7    97.3  121.0  147.5  40.905
# 8   106.2  124.2  150.1  32.905
# 9   104.7  122.1  146.4  32.224
# 10  105.2  121.4  145.2  31.622
# 11   96.2  116.3  143.5  52.536
# 12   88.3  110.6  139.8  46.752
# 13   89.2  110.5  140.9  46.849
# 14  105.1  120.8  144.7  31.658
# 15   99.8  119.3  146.4  39.536
# 16   95.3  112.8  142.1  48.258
# 17  104.5  120.6  143.8  31.273
# 18  100.5  119.6  144.5  37.465
# 19   91.0  112.5  140.1  47.162
# 20   95.0  117.9  148.1  49.666
# 21  104.9  121.4  145.7  31.989
# 22   99.4  119.3  145.2  39.506
# 23   91.9  112.5  142.7  46.499
# 24   99.8  120.3  146.6  41.350
# 25  105.4  121.3  144.3  31.741
# 26  106.4  123.8  148.9  32.942
# 27   89.9  111.0  143.1  47.926
# 28  102.9  120.8  145.9  34.467
# 29  104.1  121.5  145.4  32.446
#
#     Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 0                                              10.0
# 1                                              10.0
# 2                                              30.0
# 3                                              10.0
# 4                                              20.0
# 5                                              30.0
# 6                                              10.0
# 7                                              30.0
# 8                                              30.0
# 9                                              30.0
# 10                                             20.0
# 11                                             30.0
# 12                                             10.0
# 13                                             10.0
# 14                                             10.0
# 15                                             20.0
# 16                                             20.0
# 17                                             30.0
# 18                                             20.0
# 19                                             10.0
# 20                                             10.0
# 21                                             30.0
# 22                                             20.0
# 23                                             30.0
# 24                                             30.0
# 25                                             10.0
# 26                                             10.0
# 27                                             30.0
# 28                                             20.0
# 29                                             10.0
#
#     Case Conditions_C7+ in Light End (Input)_wt%  \
# 0                                           10.0
# 1                                            2.5
# 2                                            2.5
# 3                                           10.0
# 4                                            5.0
# 5                                            2.5
# 6                                           10.0
# 7                                           10.0
# 8                                            5.0
# 9                                           10.0
# 10                                           2.5
# 11                                           2.5
# 12                                           2.5
# 13                                           2.5
# 14                                          10.0
# 15                                           2.5
# 16                                           5.0
# 17                                           2.5
# 18                                          10.0
# 19                                           5.0
# 20                                           2.5
# 21                                          10.0
# 22                                           5.0
# 23                                          10.0
# 24                                           2.5
# 25                                          10.0
# 26                                          10.0
# 27                                           2.5
# 28                                           5.0
# 29                                           5.0
#
#     Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 0                                               100.0
# 1                                               100.0
# 2                                               100.0
# 3                                               100.0
# 4                                               100.0
# 5                                                90.0
# 6                                               100.0
# 7                                               100.0
# 8                                               100.0
# 9                                               100.0
# 10                                              100.0
# 11                                              100.0
# 12                                              100.0
# 13                                               90.0
# 14                                              100.0
# 15                                              100.0
# 16                                              100.0
# 17                                              100.0
# 18                                              100.0
# 19                                              100.0
# 20                                              110.0
# 21                                              100.0
# 22                                              100.0
# 23                                              100.0
# 24                                              100.0
# 25                                              100.0
# 26                                              100.0
# 27                                              110.0
# 28                                              100.0
# 29                                              100.0
#
#     Case Conditions_C6P- in Heart Cut (Input)_wt%
# 0                                            1.00
# 1                                            1.50
# 2                                            2.00
# 3                                            1.50
# 4                                            0.50
# 5                                            1.00
# 6                                            1.00
# 7                                            0.70
# 8                                            0.50
# 9                                            2.00
# 10                                           1.00
# 11                                           0.70
# 12                                           1.00
# 13                                           1.00
# 14                                           2.00
# 15                                           0.70
# 16                                           1.00
# 17                                           1.00
# 18                                           0.25
# 19                                           1.00
# 20                                           0.15
# 21                                           0.50
# 22                                           2.00
# 23                                           0.30
# 24                                           1.50
# 25                                           0.03
# 26                                           2.00
# 27                                           0.70
# 28                                           1.50
# 29                                           0.50

# %% [markdown]
# ## 呼叫eva得到結果

# %%
for i in tqdm(Input.index.tolist()): #測試n筆數據
    x = Input.loc[[i]] #選取一個"row"出來
    x.index = [0] #改index(重點)
    eva(x) #預測
# Out:
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
eva.predict
# Out:
#            HYD         NC1          NC2          NC3          PC4  \
# 0  2862.977297  830.499243  3618.198054  3872.478703  1670.967135
#
#             SAP         SAN          BEZ           TOL          ETB  \
# 0  16503.660894  663.342118  1808.299892  14345.812757  3757.153297
#
#            PXY           MXY          OXY           C9A          C10  \
# 0  2449.845189  11110.364541  5689.849081  13191.669622  2601.471351
#
#    Light End Product Properties_Light End Prod. Rate_ton/hr  \
# 0                                        6876.012384
#
#    Heavy End Product Properties_Heavy End Product Rate_ton/hr  \
# 0                                        8147.402475
#
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr
# 0                          2.607057                          5.807131

# %%
eva.naphtha
# Out:
#        C5NP      C5IP       C5N      C6NP      C6IP      C6N       C6A  \
# 0  0.167933  0.130937  0.100806  3.651662  1.377248  2.28294  0.491005
#
#         C7NP      C7IP       C7N  ...       C8N       C8A   C9NP      C9IP  \
# 0  10.410276  7.413772  6.387177  ...  5.109599  5.788308  6.746  10.72867
#
#         C9N       C9A     C10NP     C10IP      C10N      C10A
# 0  4.539886  3.854016  1.024243  5.886459  0.500001  0.436035
#
# [1 rows x 23 columns]

# %%
eva.pre_d
# Out:
#    Individual Component to Light End Split Factor_Oxygen_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Oxygen_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Oxygen_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Methane_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Methane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Methane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Ethane_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Ethane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Ethane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Propane_Ratio  ...  \
# 0                                           0.987319             ...
#
#    Individual Component to Heavy End Split Factor_n-Pentylbenzene_Ratio  \
# 0                                           0.484748
#
#    Individual Component to Light End Split Factor_n-Dodecane_Ratio  \
# 0                                           0.001026
#
#    Individual Component to Heart Cut Split Factor_n-Dodecane_Ratio  \
# 0                                           0.651692
#
#    Individual Component to Heavy End Split Factor_n-Dodecane_Ratio  \
# 0                                           0.347282
#
#    Individual Component to Light End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.009904
#
#    Individual Component to Heart Cut Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.511201
#
#    Individual Component to Heavy End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.478895
#
#    Individual Component to Light End Split Factor_n-Tridecane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heart Cut Split Factor_n-Tridecane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_n-Tridecane_Ratio
# 0                                                1.0
#
# [1 rows x 162 columns]

# %%
eva.reform
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0          2862.977297          830.499243        3618.198054
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         3872.478703           940.060541           730.906595
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                   0.77715            2823.63827                4268.355892
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                  23.00337  ...         11110.364541          5689.849081
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0             8.736571                   29.80326                 12.803208
#
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0            13191.669622                    88.957236
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   227.290351                  158.046378
#
#    Product    C10+ Aromtics
# 0               2601.471351
#
# [1 rows x 33 columns]
