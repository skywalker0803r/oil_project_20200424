# %%
from API.utils import EVA
from API.utils import *
import joblib
from tqdm import tqdm_notebook as tqdm

# %%
col_names = joblib.load('./data/phase_2/cleaned/col_names.pkl')
eva = EVA()

# %% [markdown]
# ## 準備輸入資料

# %%
x4 = pd.read_csv('./data/phase_1/test_170.csv',index_col=0).sample(30)[['T10','T50','T90','N+A']].reset_index(drop=True)

# %%
case4 = pd.read_csv('./data/phase_2/cleaned/train.csv',index_col=0)[col_names['case']].sample(30).reset_index(drop=True)

# %%
Input = x4.join(case4)
Input
# Out:
#       T10    T50    T90     N+A  \
# 0   106.6  121.8  147.1  30.971
# 1   102.8  125.4  144.8  34.289
# 2   105.1  120.8  144.7  31.658
# 3   105.0  120.9  144.2  30.992
# 4    92.2  113.4  142.4  45.413
# 5    99.5  119.7  146.2  39.901
# 6    96.9  120.2  145.7  42.151
# 7    89.6  110.8  142.0  46.747
# 8    95.8  116.2  145.0  48.599
# 9    96.2  116.3  143.5  52.536
# 10   90.0  105.4  136.9  56.256
# 11  104.5  120.6  143.8  31.273
# 12   91.6  113.4  145.2  49.827
# 13   96.3  119.1  146.5  46.354
# 14  101.0  119.9  145.2  36.006
# 15  105.5  121.4  145.7  31.197
# 16  105.4  122.6  148.2  32.418
# 17   99.4  120.1  145.8  38.941
# 18  105.6  121.7  145.8  31.642
# 19   91.2  109.0  140.2  54.316
# 20   95.0  117.0  145.8  50.609
# 21  105.2  120.5  143.9  31.796
# 22  105.7  121.5  147.2  31.846
# 23  100.8  119.3  143.1  36.631
# 24  105.4  122.4  147.6  31.390
# 25  105.8  124.1  149.2  32.986
# 26  104.1  121.5  145.4  32.446
# 27   92.6  109.9  139.3  55.588
# 28  101.0  120.3  146.0  37.045
# 29  104.9  121.4  145.7  31.989
#
#     Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 0                                              20.0
# 1                                              10.0
# 2                                              10.0
# 3                                              30.0
# 4                                              30.0
# 5                                              10.0
# 6                                              30.0
# 7                                              10.0
# 8                                              20.0
# 9                                              10.0
# 10                                             30.0
# 11                                             20.0
# 12                                             10.0
# 13                                             20.0
# 14                                             10.0
# 15                                             20.0
# 16                                             30.0
# 17                                             20.0
# 18                                             20.0
# 19                                             20.0
# 20                                             10.0
# 21                                             30.0
# 22                                             10.0
# 23                                             10.0
# 24                                             20.0
# 25                                             10.0
# 26                                             30.0
# 27                                             30.0
# 28                                             30.0
# 29                                             20.0
#
#     Case Conditions_C7+ in Light End (Input)_wt%  \
# 0                                            2.5
# 1                                            2.5
# 2                                            2.5
# 3                                           10.0
# 4                                            5.0
# 5                                           10.0
# 6                                            2.5
# 7                                            2.5
# 8                                           10.0
# 9                                           10.0
# 10                                           2.5
# 11                                          10.0
# 12                                           5.0
# 13                                           5.0
# 14                                          10.0
# 15                                          10.0
# 16                                           2.5
# 17                                           5.0
# 18                                          10.0
# 19                                          10.0
# 20                                          10.0
# 21                                           5.0
# 22                                          10.0
# 23                                           2.5
# 24                                           2.5
# 25                                          10.0
# 26                                           2.5
# 27                                           2.5
# 28                                           5.0
# 29                                          10.0
#
#     Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 0                                               100.0
# 1                                               100.0
# 2                                               100.0
# 3                                               100.0
# 4                                               100.0
# 5                                               100.0
# 6                                               100.0
# 7                                                90.0
# 8                                               100.0
# 9                                               100.0
# 10                                               90.0
# 11                                              100.0
# 12                                              100.0
# 13                                              100.0
# 14                                              100.0
# 15                                              100.0
# 16                                              100.0
# 17                                              100.0
# 18                                              100.0
# 19                                              100.0
# 20                                              100.0
# 21                                              100.0
# 22                                              100.0
# 23                                              100.0
# 24                                              100.0
# 25                                              100.0
# 26                                               90.0
# 27                                               90.0
# 28                                              100.0
# 29                                              100.0
#
#     Case Conditions_C6P- in Heart Cut (Input)_wt%
# 0                                            0.70
# 1                                            1.50
# 2                                            2.00
# 3                                            1.00
# 4                                            0.01
# 5                                            0.30
# 6                                            1.50
# 7                                            0.70
# 8                                            1.50
# 9                                            0.50
# 10                                           1.00
# 11                                           1.50
# 12                                           2.00
# 13                                           1.50
# 14                                           1.00
# 15                                           1.50
# 16                                           1.00
# 17                                           2.00
# 18                                           1.00
# 19                                           1.00
# 20                                           1.00
# 21                                           1.00
# 22                                           1.00
# 23                                           1.50
# 24                                           2.00
# 25                                           1.00
# 26                                           1.50
# 27                                           1.00
# 28                                           0.70
# 29                                           1.50

# %% [markdown]
# ## 呼叫eva得到結果

# %%
for i in tqdm(Input.index.tolist()): #測試n筆數據
    x = Input.loc[[i]] #選取一個"row"出來
    x.index = [0] #改index(重點)
    eva(x) #預測
# Out:
# HBox(children=(IntProgress(value=0, max=30), HTML(value='')))

# %%
eva.predict
# Out:
#            HYD         NC1          NC2          NC3          PC4  \
# 0  2874.585514  833.117946  3637.303351  3948.322595  1541.164162
#
#             SAP         SAN          BEZ           TOL          ETB  \
# 0  16643.236609  653.189378  1838.942486  14318.777946  3715.177946
#
#            PXY           MXY          OXY           C9A         C10  \
# 0  2415.231568  11062.638703  5646.668973  13143.360865  2631.98573
#
#    Light End Product Properties_Light End Prod. Rate_ton/hr  \
# 0                                         5677.32316
#
#    Heavy End Product Properties_Heavy End Product Rate_ton/hr  \
# 0                                         9418.98152
#
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr
# 0                          2.606482                          3.614788

# %%
eva.naphtha
# Out:
#        C5NP      C5IP       C5N     C6NP      C6IP       C6N       C6A  \
# 0  0.102974  0.094275  0.100255  3.50206  1.173806  2.200068  0.449969
#
#         C7NP      C7IP       C7N  ...       C8N       C8A      C9NP  \
# 0  10.681571  7.711746  6.340314  ...  5.041279  5.697553  6.814194
#
#         C9IP       C9N       C9A     C10NP     C10IP      C10N      C10A
# 0  10.853741  4.509895  3.757767  0.978871  5.735749  0.518994  0.424854
#
# [1 rows x 23 columns]

# %%
eva.pre_d
# Out:
#    Individual Component to Light End Split Factor_Oxygen_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Oxygen_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Oxygen_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Methane_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Methane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Methane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Ethane_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Ethane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Ethane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Propane_Ratio  ...  \
# 0                                           0.999256             ...
#
#    Individual Component to Heavy End Split Factor_n-Pentylbenzene_Ratio  \
# 0                                           0.424511
#
#    Individual Component to Light End Split Factor_n-Dodecane_Ratio  \
# 0                                           0.000133
#
#    Individual Component to Heart Cut Split Factor_n-Dodecane_Ratio  \
# 0                                           0.502881
#
#    Individual Component to Heavy End Split Factor_n-Dodecane_Ratio  \
# 0                                           0.496987
#
#    Individual Component to Light End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.000076
#
#    Individual Component to Heart Cut Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.496174
#
#    Individual Component to Heavy End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                            0.50375
#
#    Individual Component to Light End Split Factor_n-Tridecane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heart Cut Split Factor_n-Tridecane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_n-Tridecane_Ratio
# 0                                                1.0
#
# [1 rows x 162 columns]

# %%
eva.reform
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0          2874.585514          833.117946        3637.303351
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         3948.322595           864.243081           676.921081
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                  0.805609            2835.39027                4288.313081
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                 22.778333  ...         11062.638703          5646.668973
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0             8.960533                  30.646236                  12.26416
#
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0            13143.360865                    83.954514
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   216.683284                  151.959554
#
#    Product    C10+ Aromtics
# 0                2631.98573
#
# [1 rows x 33 columns]
