# %%
from API.utils import EVA
from API.utils import *
import joblib
from tqdm import tqdm_notebook as tqdm

# %%
col_names = joblib.load('./data/phase_2/cleaned/col_names.pkl')
eva = EVA()

# %% [markdown]
# ## 準備輸入資料

# %%
x4 = pd.read_csv('./data/phase_1/test_170.csv',index_col=0).sample(30)[['T10','T50','T90','N+A']].reset_index(drop=True)

# %%
case4 = pd.read_csv('./data/phase_2/cleaned/train.csv',index_col=0)[col_names['case']].sample(30).reset_index(drop=True)

# %%
Input = x4.join(case4)
Input
# Out:
#       T10    T50    T90      N+A  \
# 0    88.1  110.9  143.8  46.7730
# 1   105.9  122.4  146.6  31.3343
# 2    96.9  120.2  145.7  42.1510
# 3   100.7  119.8  145.8  37.0610
# 4    94.9  112.7  140.3  48.9000
# 5   105.7  121.5  147.2  31.8460
# 6   102.8  125.4  144.8  34.2890
# 7   102.9  120.8  145.9  34.4670
# 8    99.9  120.1  145.8  39.8780
# 9    96.5  117.8  142.3  49.7490
# 10   91.5  112.9  141.7  47.2100
# 11  100.5  119.6  144.5  37.4650
# 12   93.6  117.5  146.7  47.5230
# 13   97.3  121.0  147.5  40.9050
# 14  105.8  121.9  146.2  32.1410
# 15   90.5  115.7  147.3  45.5850
# 16  106.4  123.8  148.9  32.9420
# 17   86.9  109.3  139.9  47.0800
# 18   94.8  118.4  146.2  42.4540
# 19   90.6  113.3  142.4  47.2780
# 20   96.1  115.9  142.1  52.4500
# 21   88.7  112.8  144.2  46.6100
# 22   95.1  117.4  145.1  49.1850
# 23   95.6  116.4  144.0  51.7420
# 24  105.4  122.6  148.2  32.4180
# 25  105.6  121.7  145.8  31.6420
# 26   90.3  111.8  143.5  47.6040
# 27   89.2  110.5  140.9  46.8490
# 28  105.6  122.1  146.6  32.8810
# 29   99.5  119.8  146.3  39.1660
#
#     Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 0                                              10.0
# 1                                              20.0
# 2                                              10.0
# 3                                              10.0
# 4                                              10.0
# 5                                              30.0
# 6                                              30.0
# 7                                              10.0
# 8                                              30.0
# 9                                              20.0
# 10                                             30.0
# 11                                             10.0
# 12                                             20.0
# 13                                             30.0
# 14                                             10.0
# 15                                             20.0
# 16                                             20.0
# 17                                             10.0
# 18                                             30.0
# 19                                             10.0
# 20                                             30.0
# 21                                             10.0
# 22                                             30.0
# 23                                             20.0
# 24                                             30.0
# 25                                             30.0
# 26                                             30.0
# 27                                             10.0
# 28                                             20.0
# 29                                             30.0
#
#     Case Conditions_C7+ in Light End (Input)_wt%  \
# 0                                            5.0
# 1                                            5.0
# 2                                            2.5
# 3                                            5.0
# 4                                            2.5
# 5                                            5.0
# 6                                            2.5
# 7                                           10.0
# 8                                           10.0
# 9                                            2.5
# 10                                           2.5
# 11                                          10.0
# 12                                           5.0
# 13                                           5.0
# 14                                           2.5
# 15                                           2.5
# 16                                          10.0
# 17                                           5.0
# 18                                          10.0
# 19                                          10.0
# 20                                           2.5
# 21                                           2.5
# 22                                           2.5
# 23                                           5.0
# 24                                           5.0
# 25                                           2.5
# 26                                          10.0
# 27                                           2.5
# 28                                           2.5
# 29                                           2.5
#
#     Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 0                                               100.0
# 1                                               100.0
# 2                                               100.0
# 3                                               100.0
# 4                                               100.0
# 5                                               100.0
# 6                                               110.0
# 7                                               100.0
# 8                                               100.0
# 9                                                90.0
# 10                                              100.0
# 11                                              100.0
# 12                                              100.0
# 13                                              100.0
# 14                                              100.0
# 15                                              110.0
# 16                                              100.0
# 17                                              100.0
# 18                                              100.0
# 19                                              100.0
# 20                                               90.0
# 21                                              100.0
# 22                                              110.0
# 23                                              100.0
# 24                                              100.0
# 25                                              100.0
# 26                                              100.0
# 27                                               90.0
# 28                                              110.0
# 29                                              100.0
#
#     Case Conditions_C6P- in Heart Cut (Input)_wt%
# 0                                            0.50
# 1                                            2.00
# 2                                            2.00
# 3                                            2.00
# 4                                            2.00
# 5                                            0.30
# 6                                            1.00
# 7                                            1.50
# 8                                            1.50
# 9                                            1.00
# 10                                           2.50
# 11                                           1.00
# 12                                           0.70
# 13                                           1.50
# 14                                           1.50
# 15                                           2.00
# 16                                           0.05
# 17                                           0.50
# 18                                           2.00
# 19                                           2.00
# 20                                           0.70
# 21                                           2.00
# 22                                           0.50
# 23                                           1.00
# 24                                           2.00
# 25                                           2.50
# 26                                           1.00
# 27                                           0.50
# 28                                           1.00
# 29                                           2.00

# %% [markdown]
# ## 呼叫eva得到結果

# %%
for i in tqdm(Input.index.tolist()): #測試n筆數據
    x = Input.loc[[i]] #選取一個"row"出來
    x.index = [0] #改index(重點)
    eva(x) #預測
# Out:
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
eva.predict
# Out:
#         HYD         NC1          NC2          NC3          PC4           SAP  \
# 0  2802.328  962.298162  2750.768649  3363.265514  1539.418216  15147.289732
#
#           SAN          BEZ           TOL         ETB          PXY  \
# 0  691.068422  2480.082162  15719.178378  3659.68173  2500.855351
#
#             MXY       OXY           C9A          C10  \
# 0  11026.067027  5541.136  11422.394811  2371.550054
#
#    Light End Product Properties_Light End Prod. Rate_ton/hr  \
# 0                                        8207.378571
#
#    Heavy End Product Properties_Heavy End Product Rate_ton/hr  \
# 0                                         9815.23937
#
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr
# 0                          2.595877                          4.087385

# %%
eva.naphtha
# Out:
#        C5NP      C5IP       C5N      C6NP      C6IP       C6N      C6A  \
# 0  1.041212  0.711142  0.147649  3.628631  2.132778  3.357054  0.64617
#
#        C7NP      C7IP       C7N  ...       C8N       C8A      C9NP      C9IP  \
# 0  8.377666  6.470948  9.018998  ...  6.815034  5.969351  5.443322  9.549486
#
#         C9N      C9A     C10NP     C10IP      C10N      C10A
# 0  4.960643  3.64674  1.161547  5.434661  0.658504  0.687956
#
# [1 rows x 23 columns]

# %%
eva.pre_d
# Out:
#    Individual Component to Light End Split Factor_Oxygen_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Oxygen_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Oxygen_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Methane_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Methane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Methane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Ethane_Ratio  \
# 0                                                1.0
#
#    Individual Component to Heart Cut Split Factor_Ethane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_Ethane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Light End Split Factor_Propane_Ratio  ...  \
# 0                                           0.987625             ...
#
#    Individual Component to Heavy End Split Factor_n-Pentylbenzene_Ratio  \
# 0                                           0.454563
#
#    Individual Component to Light End Split Factor_n-Dodecane_Ratio  \
# 0                                           0.000003
#
#    Individual Component to Heart Cut Split Factor_n-Dodecane_Ratio  \
# 0                                           0.548926
#
#    Individual Component to Heavy End Split Factor_n-Dodecane_Ratio  \
# 0                                            0.45107
#
#    Individual Component to Light End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.002624
#
#    Individual Component to Heart Cut Split Factor_n-Hexylbenzene_Ratio  \
# 0                                            0.54658
#
#    Individual Component to Heavy End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.450796
#
#    Individual Component to Light End Split Factor_n-Tridecane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heart Cut Split Factor_n-Tridecane_Ratio  \
# 0                                                0.0
#
#    Individual Component to Heavy End Split Factor_n-Tridecane_Ratio
# 0                                                1.0
#
# [1 rows x 162 columns]

# %%
eva.reform
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0             2802.328          962.298162        2750.768649
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         3363.265514           840.431459           698.986757
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                  1.295232           2323.895135                3529.005405
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                 39.656699  ...         11026.067027             5541.136
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0            16.354534                     65.621                 23.185351
#
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0            11422.394811                   102.252899
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   200.528419                  140.351338
#
#    Product    C10+ Aromtics
# 0               2371.550054
#
# [1 rows x 33 columns]
