# %%
from API.utils import EVA
from API.utils import *
import joblib
from tqdm import tqdm_notebook as tqdm

# %%
col_names = joblib.load('./data/phase_2/cleaned/col_names.pkl')
eva = EVA()

# %% [markdown]
# ## 準備輸入資料

# %%
x4 = pd.read_csv('./data/phase_1/test_170.csv',index_col=0).sample(30)[['T10','T50','T90','N+A']].reset_index(drop=True)

# %%
case4 = pd.read_csv('./data/phase_2/cleaned/train.csv',index_col=0)[col_names['case']].sample(30).reset_index(drop=True)

# %%
Input = x4.join(case4)
Input
# Out:
#       T10    T50    T90     N+A  \
# 0    93.6  117.5  146.7  47.523
# 1   100.5  119.6  144.5  37.465
# 2   104.5  120.9  145.6  32.249
# 3   106.1  124.0  150.3  33.005
# 4   105.6  121.3  144.0  32.560
# 5   102.7  120.7  145.8  35.144
# 6   105.6  122.6  146.7  32.547
# 7    94.3  117.4  146.9  43.706
# 8   102.8  125.4  144.8  34.289
# 9   107.2  123.8  149.2  32.881
# 10   97.5  121.2  148.8  41.499
# 11  105.6  121.2  146.7  31.405
# 12   99.9  119.9  146.9  41.307
# 13  105.4  121.3  144.3  31.741
# 14   90.7  116.1  146.4  45.964
# 15   99.4  120.1  145.8  38.941
# 16  104.8  121.1  145.4  31.690
# 17   89.2  110.1  141.4  47.761
# 18   96.9  120.2  145.7  42.151
# 19  104.3  120.8  145.4  31.887
# 20  105.5  121.4  145.7  31.197
# 21  104.0  122.2  148.1  32.647
# 22   90.4  105.5  136.1  56.766
# 23   96.3  117.1  144.2  50.734
# 24  105.1  120.8  144.7  31.658
# 25   92.6  109.9  139.3  55.588
# 26  105.4  121.7  146.0  33.237
# 27  100.7  119.8  145.8  37.061
# 28   97.3  121.0  147.5  40.905
# 29  100.8  119.3  143.1  36.631
#
#     Case Conditions_Feed Rate to C013 (Input)_m3/hr  \
# 0                                              20.0
# 1                                              30.0
# 2                                              20.0
# 3                                              30.0
# 4                                              10.0
# 5                                              10.0
# 6                                              20.0
# 7                                              30.0
# 8                                              30.0
# 9                                              10.0
# 10                                             10.0
# 11                                             10.0
# 12                                             30.0
# 13                                             30.0
# 14                                             30.0
# 15                                             10.0
# 16                                             30.0
# 17                                             30.0
# 18                                             10.0
# 19                                             30.0
# 20                                             10.0
# 21                                             20.0
# 22                                             30.0
# 23                                             30.0
# 24                                             30.0
# 25                                             10.0
# 26                                             10.0
# 27                                             30.0
# 28                                             30.0
# 29                                             30.0
#
#     Case Conditions_C7+ in Light End (Input)_wt%  \
# 0                                            2.5
# 1                                            2.5
# 2                                            2.5
# 3                                            2.5
# 4                                           10.0
# 5                                           10.0
# 6                                            5.0
# 7                                           10.0
# 8                                            2.5
# 9                                            5.0
# 10                                           5.0
# 11                                           2.5
# 12                                           5.0
# 13                                           2.5
# 14                                          10.0
# 15                                           2.5
# 16                                           2.5
# 17                                           5.0
# 18                                           5.0
# 19                                           2.5
# 20                                           2.5
# 21                                           2.5
# 22                                           2.5
# 23                                           5.0
# 24                                          10.0
# 25                                          10.0
# 26                                           5.0
# 27                                           5.0
# 28                                           2.5
# 29                                           2.5
#
#     Case Conditions_Heart Cut Prod. Rate (Input)_m3/hr  \
# 0                                               100.0
# 1                                               110.0
# 2                                               100.0
# 3                                               100.0
# 4                                               100.0
# 5                                               100.0
# 6                                               100.0
# 7                                               100.0
# 8                                               100.0
# 9                                               100.0
# 10                                              100.0
# 11                                              110.0
# 12                                              100.0
# 13                                              100.0
# 14                                              100.0
# 15                                              100.0
# 16                                              100.0
# 17                                              100.0
# 18                                              100.0
# 19                                              100.0
# 20                                              100.0
# 21                                              100.0
# 22                                              100.0
# 23                                              100.0
# 24                                              100.0
# 25                                              100.0
# 26                                              100.0
# 27                                              100.0
# 28                                              110.0
# 29                                              110.0
#
#     Case Conditions_C6P- in Heart Cut (Input)_wt%
# 0                                             1.5
# 1                                             1.0
# 2                                             1.0
# 3                                             1.5
# 4                                             1.5
# 5                                             1.5
# 6                                             2.0
# 7                                             1.5
# 8                                             0.3
# 9                                             1.0
# 10                                            1.0
# 11                                            1.0
# 12                                            0.7
# 13                                            1.5
# 14                                            0.7
# 15                                            1.0
# 16                                            1.5
# 17                                            0.5
# 18                                            1.5
# 19                                            0.3
# 20                                            2.0
# 21                                            1.5
# 22                                            1.0
# 23                                            0.5
# 24                                            1.0
# 25                                            1.5
# 26                                            1.5
# 27                                            1.0
# 28                                            1.0
# 29                                            1.5

# %% [markdown]
# ## 呼叫eva得到結果

# %%
for i in tqdm(Input.index.tolist()): #測試n筆數據
    x = Input.loc[[i]] #選取一個"row"出來
    x.index = [0] #改index(重點)
    eva(x) #預測
# Out:
# HBox(children=(FloatProgress(value=0.0, max=30.0), HTML(value='')))

# %%
eva.predict
# Out:
#            HYD         NC1          NC2          NC3          PC4  \
# 0  2847.986162  901.552108  3175.082811  3799.782919  1398.338162
#
#             SAP         SAN          BEZ           TOL          ETB  \
# 0  15559.520864  589.863638  2126.651027  15100.426378  3726.446703
#
#            PXY           MXY          OXY           C9A       C10  \
# 0  2269.911784  11678.478703  5730.192865  12558.152649  2247.856
#
#    Light End Product Properties_Light End Prod. Rate_ton/hr  \
# 0                                        7191.836651
#
#    Heavy End Product Properties_Heavy End Product Rate_ton/hr  \
# 0                                        9097.918319
#
#    Duty_E062 3.5K Steam Rate_ton/hr  Duty_Reboiler Heat Duty_Mkcal/hr
# 0                          2.600629                          4.787864

# %%
eva.naphtha
# Out:
#       C5NP      C5IP       C5N      C6NP      C6IP       C6N       C6A  \
# 0  0.56602  0.363641  0.121185  3.763924  1.796549  3.071245  0.601434
#
#       C7NP      C7IP       C7N  ...       C8N       C8A      C9NP      C9IP  \
# 0  9.56826  7.043784  8.100408  ...  6.195165  6.040584  5.983717  9.836066
#
#         C9N       C9A     C10NP     C10IP      C10N     C10A
# 0  4.844295  3.568201  0.841759  5.141482  0.477128  0.42186
#
# [1 rows x 23 columns]

# %%
eva.pre_d
# Out:
#    Individual Component to Light End Split Factor_Oxygen_Ratio  \
# 0                                           0.999509
#
#    Individual Component to Heart Cut Split Factor_Oxygen_Ratio  \
# 0                                           0.000216
#
#    Individual Component to Heavy End Split Factor_Oxygen_Ratio  \
# 0                                           0.000275
#
#    Individual Component to Light End Split Factor_Methane_Ratio  \
# 0                                           0.999438
#
#    Individual Component to Heart Cut Split Factor_Methane_Ratio  \
# 0                                           0.000293
#
#    Individual Component to Heavy End Split Factor_Methane_Ratio  \
# 0                                            0.00027
#
#    Individual Component to Light End Split Factor_Ethane_Ratio  \
# 0                                           0.999441
#
#    Individual Component to Heart Cut Split Factor_Ethane_Ratio  \
# 0                                           0.000375
#
#    Individual Component to Heavy End Split Factor_Ethane_Ratio  \
# 0                                           0.000184
#
#    Individual Component to Light End Split Factor_Propane_Ratio  ...  \
# 0                                           0.986979             ...
#
#    Individual Component to Heavy End Split Factor_n-Pentylbenzene_Ratio  \
# 0                                           0.473405
#
#    Individual Component to Light End Split Factor_n-Dodecane_Ratio  \
# 0                                            0.00002
#
#    Individual Component to Heart Cut Split Factor_n-Dodecane_Ratio  \
# 0                                             0.5183
#
#    Individual Component to Heavy End Split Factor_n-Dodecane_Ratio  \
# 0                                            0.48168
#
#    Individual Component to Light End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.000169
#
#    Individual Component to Heart Cut Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.517818
#
#    Individual Component to Heavy End Split Factor_n-Hexylbenzene_Ratio  \
# 0                                           0.482013
#
#    Individual Component to Light End Split Factor_n-Tridecane_Ratio  \
# 0                                           0.000272
#
#    Individual Component to Heart Cut Split Factor_n-Tridecane_Ratio  \
# 0                                           0.000324
#
#    Individual Component to Heavy End Split Factor_n-Tridecane_Ratio
# 0                                           0.999404
#
# [1 rows x 162 columns]

# %%
eva.reform
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0          2847.986162          901.552108        3175.082811
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         3799.782919           774.323946           624.014216
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                  0.963984           2633.795676                3979.285622
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                 23.782588  ...         11678.478703          5730.192865
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0             9.756883                  34.153497                 12.961712
#
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0            12558.152649                    75.758838
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   174.667716                  122.367257
#
#    Product    C10+ Aromtics
# 0                  2247.856
#
# [1 rows x 33 columns]
