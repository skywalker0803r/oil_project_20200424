# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import math
import xgboost
from sklearn.cross_decomposition import PLSRegression
from sklearn.ensemble import RandomForestRegressor
import pandas as pd
import os

os.listdir('../data/phase_2/raw/other')
# Out:
# ['other', 'PROII20200310']

# %%
data = pd.read_csv("200mb201701r2.csv", encoding = 'big5', header = 0)
print('讀檔案 : ' + str(data.shape))
testdata = pd.read_csv("200mb201909.csv", encoding = 'big5', header = 0)
# steam = dcs['ARO1-DCS-FIC55301'] + dcs['ARO1-DCS-FIC55501'] + dcs['ARO1-DCS-FIC55601']
# dcs['steam'] = steam
C9A = data['Feed    C9 Aromtics'] + data['Feed    C10+ Aromtics']
AROMA = data['Product    C9 Aromtics'] + data['Product    C10+ Aromtics']+ data['Product    Benzene']+ data['Product    Toluene']+ data['Product    Ethylbenzene']+ data['Product    P-Xylene']+ data['Product    M-Xylene']+ data['Product    O-Xylene']
data['C9A'] = C9A
data['AROMA'] = AROMA
C9A = testdata['Feed    C9 Aromtics'] + testdata['Feed    C10+ Aromtics']
AROMA = testdata['Product    C9 Aromtics'] + testdata['Product    C10+ Aromtics']+ testdata['Product    Benzene']+ testdata['Product    Toluene']+ testdata['Product    Ethylbenzene']+ testdata['Product    P-Xylene']+ testdata['Product    M-Xylene']+ testdata['Product    O-Xylene']
testdata['C9A'] = C9A
testdata['AROMA'] = AROMA
# Out:
# 讀檔案 : (829, 108)

# %%
print ("Shape Of The Before Ouliers: ",data.shape)
data = data[(data["Naphtha Feed Rate, m3/hr"]<=100 )&(data["Naphtha Feed Rate, m3/hr"] >= 99)]
print ("Shape Of The After Ouliers: ",data.shape)
print ("Shape Of The Before Ouliers: ",testdata.shape)
testdata = testdata[(testdata["Naphtha Feed Rate, m3/hr"]<=100 )&(testdata["Naphtha Feed Rate, m3/hr"] >= 99)]
print ("Shape Of The After Ouliers: ",testdata.shape)
testdata.index = range(len(testdata))
# Out:
# Shape Of The Before Ouliers:  (829, 110)
# Shape Of The After Ouliers:  (576, 110)
# Shape Of The Before Ouliers:  (27, 110)
# Shape Of The After Ouliers:  (20, 110)

# %%
data.describe()
# Out:
#        MB Deviation of Compensated Data(%)  Reformer Loading, %  \
# count                           576.000000           576.000000
# mean                              0.058998           133.977164
# std                               0.959343             0.319770
# min                              -3.498033           133.249003
# 25%                              -0.331510           133.736450
# 50%                               0.111284           133.987044
# 75%                               0.616033           134.217675
# max                               2.460408           134.580784
#
#        Naphtha Feed Rate, m3/hr      N+2A in Naphtha Feed, wt%  \
# count                576.000000                     576.000000
# mean                  99.545033                      53.459728
# std                    0.237589                       3.897849
# min                   99.004009                      44.096529
# 25%                   99.366183                      50.982861
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 576 entries, 0 to 828
# Columns: 110 entries, Unnamed: 0 to AROMA
# dtypes: float64(105), int64(3), object(2)
# memory usage: 499.5+ KB

# %%
Xcol  = [
"    N+2A in Naphtha Feed, wt%", #"ARO1-LIMS-s201-Naphthenes-ALL" + 2*"ARO1-LIMS-s201-Aromatics-ALL"
"    Chlorine in Fresh Catalyst, wt%", #"ARO1-LIMS-S307-CL"
"Carbon in Spent Catalyst, %",  #"ARO1-LIMS-S301-CARBON"  
"    C6P- in Naphtha Feed, wt%",  #"ARO1-LIMS-s201-Paraffins-6"  
"    3R211 Inlet Tem, oC",  #"ARO1-DCS-TIC20102 Setpoint"
"    3R212 Inlet Temp, oC", #"ARO1-DCS-TIC20202 Setpoint"
"    3R213 Inlet Temp, oC", #"ARO1-DCS-TIC20302 Setpoint"
"    3R214 Inlet Temp, oC", #"ARO1-DCS-TIC20402 Setpoint"
"Feed    Hydrogen",
"Feed    Methane",
"Feed    Ethane",
"Feed    Propane",
"Feed    n-Butane",
"Feed    i-Butane",
"Feed    C4 Naphthenes",
"Feed    n-Pentane",
"Feed    C5 i-Paraffins",
"Feed    C5 Naphthenes",
"Feed    n-Hexane",
"Feed    C6 i-Paraffins",
"Feed    C6 Naphthenes",
"Feed    Benzene",
"Feed    n-Heptane",
"Feed    C7 i-Paraffins",
"Feed    C7 Naphthenes",
"Feed    Toluene",
"Feed    n-Octane",
"Feed    C8 i-Paraffins",
"Feed    C8 Naphthenes",
"Feed    Ethylbenzene",
"Feed    P-Xylene",
"Feed    M-Xylene",
"Feed    O-Xylene",
"Feed    n-Nonane",
"Feed    C9 i-Paraffins",
"Feed    C9 Naphthenes",
"Feed    C9 Aromtics",
"Feed    C10+ n-Paraffins",
"Feed    C10+ i-Paraffins",
"Feed    C10+ Naphthenes",
"Feed    C10+ Aromtics",
"Product Separator Pressure, kg/cm2_g", #"ARO1-DCS-PIC21501 Setpoint"
# "Product Separator Temp, oC",
"H2/HC Ratio"                           #"ARO1-DCS-R211_HC"
         
         ]

# %%
X = data[Xcol]
y1 = data["Product    Hydrogen"]
y2 = data["Product    Methane"]
y3 = data["Product    Ethane"]
y4 = data["Product    Propane"]
y5 = data["Product    n-Butane"]
y6 = data["Product    i-Butane"]
y7 = data["Product    C4 Naphthenes"]
y8 = data["Product    n-Pentane"]
y9 = data["Product    C5 i-Paraffins"]
y10 = data["Product    C5 Naphthenes"]
y11 = data["Product    n-Hexane"]
y12 = data["Product    C6 i-Paraffins"]
y13 = data["Product    C6 Naphthenes"]
y14 = data["Product    Benzene"]
y15 = data["Product    n-Heptane"]
y16 = data["Product    C7 i-Paraffins"]
y17 = data["Product    C7 Naphthenes"]
y18 = data["Product    Toluene"]
y19 = data["Product    n-Octane"]
y20 = data["Product    C8 i-Paraffins"]
y21 = data["Product    C8 Naphthenes"]
y22 = data["Product    Ethylbenzene"]
y23 = data["Product    P-Xylene"]
y24 = data["Product    M-Xylene"]
y25 = data["Product    O-Xylene"]
y26 = data["Product    n-Nonane"]
y27 = data["Product    C9 i-Paraffins"]
y28 = data["Product    C9 Naphthenes"]
y29 = data["Product    C9 Aromtics"]
y30 = data["Product    C10+ n-Paraffins"]
y31 = data["Product    C10+ i-Paraffins"]
y32 = data["Product    C10+ Naphthenes"]
y33 = data["Product    C10+ Aromtics"]
y34 = data["PC4"]
y35 = data["SAP"]
y36 = data["SAN"]
y37 = data["C9A"]
y38 = data["AROMA"]

Xest = testdata[Xcol]
yest1 = testdata["Product    Hydrogen"]
yest2 = testdata["Product    Methane"]
yest3 = testdata["Product    Ethane"]
yest4 = testdata["Product    Propane"]
yest5 = testdata["Product    n-Butane"]
yest6 = testdata["Product    i-Butane"]
yest7 = testdata["Product    C4 Naphthenes"]
yest8 = testdata["Product    n-Pentane"]
yest9 = testdata["Product    C5 i-Paraffins"]
yest10 = testdata["Product    C5 Naphthenes"]
yest11 = testdata["Product    n-Hexane"]
yest12 = testdata["Product    C6 i-Paraffins"]
yest13 = testdata["Product    C6 Naphthenes"]
yest14 = testdata["Product    Benzene"]
yest15 = testdata["Product    n-Heptane"]
yest16 = testdata["Product    C7 i-Paraffins"]
yest17 = testdata["Product    C7 Naphthenes"]
yest18 = testdata["Product    Toluene"]
yest19 = testdata["Product    n-Octane"]
yest20 = testdata["Product    C8 i-Paraffins"]
yest21 = testdata["Product    C8 Naphthenes"]
yest22 = testdata["Product    Ethylbenzene"]
yest23 = testdata["Product    P-Xylene"]
yest24 = testdata["Product    M-Xylene"]
yest25 = testdata["Product    O-Xylene"]
yest26 = testdata["Product    n-Nonane"]
yest27 = testdata["Product    C9 i-Paraffins"]
yest28 = testdata["Product    C9 Naphthenes"]
yest29 = testdata["Product    C9 Aromtics"]
yest30 = testdata["Product    C10+ n-Paraffins"]
yest31 = testdata["Product    C10+ i-Paraffins"]
yest32 = testdata["Product    C10+ Naphthenes"]
yest33 = testdata["Product    C10+ Aromtics"]
# yest34 = testdata["PC4"]
# yest35 = testdata["SAP"]
# yest36 = testdata["SAN"]
# yest37 = testdata["C9A"]
# yest38 = testdata["AROMA"]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.0, random_state= 42, shuffle=True)

Model_1 = LinearRegression()
Model_2 = LinearRegression()
Model_3 = LinearRegression()
Model_4 = LinearRegression()
Model_5 = LinearRegression()
Model_6 = LinearRegression()
Model_7 = LinearRegression()
Model_8 = LinearRegression()
Model_9 = LinearRegression()
Model_10 = LinearRegression()
Model_11 = LinearRegression()
Model_12 = LinearRegression()
Model_13 = LinearRegression()
Model_14 = LinearRegression()
Model_15 = LinearRegression()
Model_16 = LinearRegression()
Model_17 = LinearRegression()
Model_18 = LinearRegression()
Model_19 = LinearRegression()
Model_20 = LinearRegression()
Model_21 = LinearRegression()
Model_22 = LinearRegression()
Model_23 = LinearRegression()
Model_23 = LinearRegression()
Model_24 = LinearRegression()
Model_25 = LinearRegression()
Model_26 = LinearRegression()
Model_27 = LinearRegression()
Model_28 = LinearRegression()
Model_29 = LinearRegression()
Model_30 = LinearRegression()
Model_31 = LinearRegression()
Model_32 = LinearRegression()
Model_33 = LinearRegression()
# Model_34 = LinearRegression()
# Model_35 = LinearRegression()
# Model_36 = LinearRegression()

Model_1.fit(X, y1)
Model_2.fit(X, y2)
Model_3.fit(X, y3)
Model_4.fit(X, y4)
Model_5.fit(X, y5)
Model_6.fit(X, y6)
Model_7.fit(X, y7)
Model_8.fit(X, y8)
Model_9.fit(X, y9)
Model_10.fit(X, y10)
Model_11.fit(X, y11)
Model_12.fit(X, y12)
Model_13.fit(X, y13)
Model_14.fit(X, y14)
Model_15.fit(X, y15)
Model_16.fit(X, y16)
Model_17.fit(X, y17)
Model_18.fit(X, y18)
Model_19.fit(X, y19)
Model_20.fit(X, y20)
Model_21.fit(X, y21)
Model_22.fit(X, y22)
Model_23.fit(X, y23)
Model_24.fit(X, y24)
Model_25.fit(X, y25)
Model_26.fit(X, y26)
Model_27.fit(X, y27)
Model_28.fit(X, y28)
Model_29.fit(X, y29)
Model_30.fit(X, y30)
Model_31.fit(X, y31)
Model_32.fit(X, y32)
Model_33.fit(X, y33)
# Model_34.fit(X, y34)
# Model_35.fit(X, y35)
# Model_36.fit(X, y36)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
# from catboost import Pool, CatBoostRegressor
# Model_38 = CatBoostRegressor(iterations=500, 
#                           depth=10, 
#                           learning_rate=1, 
#                           loss_function='RMSE')

# Model_38.fit(X, y38)

# %%
import numpy as np

def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
y_pred1 = Model_1.predict(Xest)
y_pred2 = Model_2.predict(Xest)
y_pred3 = Model_3.predict(Xest)
y_pred4 = Model_4.predict(Xest)
y_pred5 = Model_5.predict(Xest)
y_pred6 = Model_6.predict(Xest)
y_pred7 = Model_7.predict(Xest)
y_pred8 = Model_8.predict(Xest)
y_pred9 = Model_9.predict(Xest)
y_pred10 = Model_10.predict(Xest)
y_pred11 = Model_11.predict(Xest)
y_pred12 = Model_12.predict(Xest)
y_pred13 = Model_13.predict(Xest)
y_pred14 = Model_14.predict(Xest)
y_pred15 = Model_15.predict(Xest)
y_pred16 = Model_16.predict(Xest)
y_pred17 = Model_17.predict(Xest)
y_pred18 = Model_18.predict(Xest)
y_pred19 = Model_19.predict(Xest)
y_pred20 = Model_20.predict(Xest)
y_pred21 = Model_21.predict(Xest)
y_pred22 = Model_22.predict(Xest)
y_pred23 = Model_23.predict(Xest)
y_pred24 = Model_24.predict(Xest)
y_pred25 = Model_25.predict(Xest)
y_pred26 = Model_26.predict(Xest)
y_pred27 = Model_27.predict(Xest)
y_pred28 = Model_28.predict(Xest)
y_pred29 = Model_29.predict(Xest)
y_pred30 = Model_30.predict(Xest)
y_pred31 = Model_31.predict(Xest)
y_pred32 = Model_32.predict(Xest)
y_pred33 = Model_33.predict(Xest)
# y_pred34 = Model_34.predict(Xest)
# y_pred35 = Model_35.predict(Xest)
# y_pred36 = Model_36.predict(Xest)
# # y_pred37 = Model_37.predict(Xest)
# y_pred38 = Model_38.predict(Xest)

# %%
from sklearn import metrics

print("MAPE1:", mean_absolute_percentage_error(yest1, y_pred1))
print("MAPE2:", mean_absolute_percentage_error(yest2, y_pred2))
print("MAPE3:", mean_absolute_percentage_error(yest3, y_pred3))
print("MAPE4:", mean_absolute_percentage_error(yest4, y_pred4))
print("MAPE5:", mean_absolute_percentage_error(yest5, y_pred5))
print("MAPE6:", mean_absolute_percentage_error(yest6, y_pred6))
print("MAPE7:", mean_absolute_percentage_error(yest7, y_pred7))
print("MAPE8:", mean_absolute_percentage_error(yest8, y_pred8))
print("MAPE9:", mean_absolute_percentage_error(yest9, y_pred9))
print("MAPE10:", mean_absolute_percentage_error(yest10, y_pred10))
print("MAPE11:", mean_absolute_percentage_error(yest11, y_pred11))
print("MAPE12:", mean_absolute_percentage_error(yest12, y_pred12))
print("MAPE13:", mean_absolute_percentage_error(yest13, y_pred13))
print("MAPE14:", mean_absolute_percentage_error(yest14, y_pred14))
print("MAPE15:", mean_absolute_percentage_error(yest15, y_pred15))
print("MAPE16:", mean_absolute_percentage_error(yest16, y_pred16))
print("MAPE17:", mean_absolute_percentage_error(yest17, y_pred17))
print("MAPE18:", mean_absolute_percentage_error(yest18, y_pred18))
print("MAPE19:", mean_absolute_percentage_error(yest19, y_pred19))
print("MAPE20:", mean_absolute_percentage_error(yest20, y_pred20))
print("MAPE21:", mean_absolute_percentage_error(yest21, y_pred21))
print("MAPE22:", mean_absolute_percentage_error(yest22, y_pred22))
print("MAPE23:", mean_absolute_percentage_error(yest23, y_pred23))
print("MAPE24:", mean_absolute_percentage_error(yest24, y_pred24))
print("MAPE25:", mean_absolute_percentage_error(yest25, y_pred25))
print("MAPE26:", mean_absolute_percentage_error(yest26, y_pred26))
print("MAPE27:", mean_absolute_percentage_error(yest27, y_pred27))
print("MAPE28:", mean_absolute_percentage_error(yest28, y_pred28))
print("MAPE29:", mean_absolute_percentage_error(yest29, y_pred29))
print("MAPE30:", mean_absolute_percentage_error(yest30, y_pred30))
print("MAPE31:", mean_absolute_percentage_error(yest31, y_pred31))
print("MAPE32:", mean_absolute_percentage_error(yest32, y_pred32))
print("MAPE33:", mean_absolute_percentage_error(yest33, y_pred33))
# print("MAPE34:", mean_absolute_percentage_error(yest34, y_pred34))
# print("MAPE35:", mean_absolute_percentage_error(yest35, y_pred35))
# print("MAPE36:", mean_absolute_percentage_error(yest36, y_pred36))
# print("MAPE37:", mean_absolute_percentage_error(yest37, y_pred37))
# print("MAPE38:", mean_absolute_percentage_error(yest38, y_pred38))
# Out:
# MAPE1: 1.6007171008231105
# MAPE2: 8.93620974708477
# MAPE3: 2.7955348888507796
# MAPE4: 7.844877682421771
# MAPE5: 8.061214106718731
# MAPE6: 12.146879465400957
# MAPE7: 10.15588738081405
# MAPE8: 5.961230633171509
# MAPE9: 5.805561450951821
# MAPE10: 3.533907466088939
# MAPE11: 5.257032784026369
# MAPE12: 4.995910341074207
# MAPE13: 20.84538053110057
# MAPE14: 2.7715293204985936
# MAPE15: 9.811208946552824
# MAPE16: 8.19123568918563
# MAPE17: 16.45088040410106
# MAPE18: 2.420278075067514
# MAPE19: 33.35393053619219
# MAPE20: 24.40965114890102
# MAPE21: 28.798158828482855
# MAPE22: 3.5271611719670624
# MAPE23: 10.251603783575627
# MAPE24: 1.5403570064435106
# MAPE25: 2.8504235562987277
# MAPE26: 43.65757153298592
# MAPE27: 59.72422798766679
# MAPE28: 16.91556119842817
# MAPE29: 2.118468198240549
# MAPE30: 7.205615959576078
# MAPE31: 7.496101869525937
# MAPE32: 7.0684415905059
# MAPE33: 4.122843643490833

# %%
Model = dict({
    'Model1': Model_1,
    'Model2': Model_2,
    'Model3': Model_3,
    'Model4': Model_4,
    'Model5': Model_5,
    'Model6': Model_6,
    'Model7': Model_7,
    'Model8': Model_8,
    'Model9': Model_9,
    'Model10': Model_10,
    'Model11': Model_11,
    'Model12': Model_12,
    'Model13': Model_13,
    'Model14': Model_14,
    'Model15': Model_15,
    'Model16': Model_16,
    'Model17': Model_17,
    'Model18': Model_18,
    'Model19': Model_19,
    'Model20': Model_20,
    'Model21': Model_21,
    'Model22': Model_22,
    'Model23': Model_23,
    'Model24': Model_24,
    'Model25': Model_25,
    'Model26': Model_26,
    'Model27': Model_27,
    'Model28': Model_28,
    'Model29': Model_29,
    'Model30': Model_30,
    'Model31': Model_31,
    'Model32': Model_32,
    'Model33': Model_33
})

# %%
import pickle 
for key,values in Model.items():
    file = open("./%s" %  key, "wb") 
    pickle.dump(values,file)

# %%
import pickle 
# 以寫二進制的方式開啟檔案 
file = open("C:/data/python/model200.pickle", "wb") 
#把模型寫入到檔案中 
pickle.dump(Model_38, file) 
# 關閉檔案 
file.close()
