# %%
import pandas as pd
import numpy as np
import warnings;warnings.simplefilter('ignore')
import os
import torch
import torchviz
from torch import nn
import torch.nn.functional as F
from torch import tensor
from torch.nn import Linear,ReLU,Sigmoid,Tanh,Dropout
import torch.optim as optim
import matplotlib.pyplot as plt

root = '../data/phase_2/raw/other/'
os.listdir(root)
# Out:
# ['200mb201701r2.csv',
#  '200mb201909.csv',
#  'Aroma-1 Unit 000 Split_Factor Calculation.xlsx',
#  'FCFC Import Naphtha Composition Lab_001~100_R2.xlsx',
#  '附件一.xlsx',
#  '附件二.xlsx']

# %% [markdown]
# # load data

# %%
data = pd.read_csv(root+"200mb201701r2.csv", encoding = 'big5', header = 0)
print('讀檔案 : ' + str(data.shape))
testdata = pd.read_csv(root+"200mb201909.csv", encoding = 'big5', header = 0)
# steam = dcs['ARO1-DCS-FIC55301'] + dcs['ARO1-DCS-FIC55501'] + dcs['ARO1-DCS-FIC55601']
# dcs['steam'] = steam
C9A = data['Feed    C9 Aromtics'] + data['Feed    C10+ Aromtics']
AROMA = data['Product    C9 Aromtics'] + data['Product    C10+ Aromtics']+ data['Product    Benzene']+ data['Product    Toluene']+ data['Product    Ethylbenzene']+ data['Product    P-Xylene']+ data['Product    M-Xylene']+ data['Product    O-Xylene']
data['C9A'] = C9A
data['AROMA'] = AROMA
C9A = testdata['Feed    C9 Aromtics'] + testdata['Feed    C10+ Aromtics']
AROMA = testdata['Product    C9 Aromtics'] + testdata['Product    C10+ Aromtics']+ testdata['Product    Benzene']+ testdata['Product    Toluene']+ testdata['Product    Ethylbenzene']+ testdata['Product    P-Xylene']+ testdata['Product    M-Xylene']+ testdata['Product    O-Xylene']
testdata['C9A'] = C9A
testdata['AROMA'] = AROMA

print ("Shape Of The Before Ouliers: ",data.shape)
data = data[(data["Naphtha Feed Rate, m3/hr"]<=100 )&(data["Naphtha Feed Rate, m3/hr"] >= 99)]
print ("Shape Of The After Ouliers: ",data.shape)
print ("Shape Of The Before Ouliers: ",testdata.shape)
testdata = testdata[(testdata["Naphtha Feed Rate, m3/hr"]<=100 )&(testdata["Naphtha Feed Rate, m3/hr"] >= 99)]
print ("Shape Of The After Ouliers: ",testdata.shape)
testdata.index = range(len(testdata))
# Out:
# 讀檔案 : (829, 108)
# Shape Of The Before Ouliers:  (829, 110)
# Shape Of The After Ouliers:  (576, 110)
# Shape Of The Before Ouliers:  (27, 110)
# Shape Of The After Ouliers:  (20, 110)

# %% [markdown]
# # x_col

# %%
x_col  = [
"    N+2A in Naphtha Feed, wt%", #"ARO1-LIMS-s201-Naphthenes-ALL" + 2*"ARO1-LIMS-s201-Aromatics-ALL"
"    Chlorine in Fresh Catalyst, wt%", #"ARO1-LIMS-S307-CL"
"Carbon in Spent Catalyst, %",  #"ARO1-LIMS-S301-CARBON"  
"    C6P- in Naphtha Feed, wt%",  #"ARO1-LIMS-s201-Paraffins-6"  
"    3R211 Inlet Tem, oC",  #"ARO1-DCS-TIC20102 Setpoint"
"    3R212 Inlet Temp, oC", #"ARO1-DCS-TIC20202 Setpoint"
"    3R213 Inlet Temp, oC", #"ARO1-DCS-TIC20302 Setpoint"
"    3R214 Inlet Temp, oC", #"ARO1-DCS-TIC20402 Setpoint"
"Feed    Hydrogen",
"Feed    Methane",
"Feed    Ethane",
"Feed    Propane",
"Feed    n-Butane",
"Feed    i-Butane",
"Feed    C4 Naphthenes",
"Feed    n-Pentane",
"Feed    C5 i-Paraffins",
"Feed    C5 Naphthenes",
"Feed    n-Hexane",
"Feed    C6 i-Paraffins",
"Feed    C6 Naphthenes",
"Feed    Benzene",
"Feed    n-Heptane",
"Feed    C7 i-Paraffins",
"Feed    C7 Naphthenes",
"Feed    Toluene",
"Feed    n-Octane",
"Feed    C8 i-Paraffins",
"Feed    C8 Naphthenes",
"Feed    Ethylbenzene",
"Feed    P-Xylene",
"Feed    M-Xylene",
"Feed    O-Xylene",
"Feed    n-Nonane",
"Feed    C9 i-Paraffins",
"Feed    C9 Naphthenes",
"Feed    C9 Aromtics",
"Feed    C10+ n-Paraffins",
"Feed    C10+ i-Paraffins",
"Feed    C10+ Naphthenes",
"Feed    C10+ Aromtics",
"Product Separator Pressure, kg/cm2_g", #"ARO1-DCS-PIC21501 Setpoint"
# "Product Separator Temp, oC",
"H2/HC Ratio"                           #"ARO1-DCS-R211_HC"
         
         ]

# %%
x_col
# Out:
# ['    N+2A in Naphtha Feed, wt%',
#  '    Chlorine in Fresh Catalyst, wt%',
#  'Carbon in Spent Catalyst, %',
#  '    C6P- in Naphtha Feed, wt%',
#  '    3R211 Inlet Tem, oC',
#  '    3R212 Inlet Temp, oC',
#  '    3R213 Inlet Temp, oC',
#  '    3R214 Inlet Temp, oC',
#  'Feed    Hydrogen',
#  'Feed    Methane',
#  'Feed    Ethane',
#  'Feed    Propane',
#  'Feed    n-Butane',
#  'Feed    i-Butane',
#  'Feed    C4 Naphthenes',
#  'Feed    n-Pentane',
#  'Feed    C5 i-Paraffins',
#  'Feed    C5 Naphthenes',
#  'Feed    n-Hexane',
#  'Feed    C6 i-Paraffins',
#  'Feed    C6 Naphthenes',
#  'Feed    Benzene',
#  'Feed    n-Heptane',
#  'Feed    C7 i-Paraffins',
#  'Feed    C7 Naphthenes',
#  'Feed    Toluene',
#  'Feed    n-Octane',
#  'Feed    C8 i-Paraffins',
#  'Feed    C8 Naphthenes',
#  'Feed    Ethylbenzene',
#  'Feed    P-Xylene',
#  'Feed    M-Xylene',
#  'Feed    O-Xylene',
#  'Feed    n-Nonane',
#  'Feed    C9 i-Paraffins',
#  'Feed    C9 Naphthenes',
#  'Feed    C9 Aromtics',
#  'Feed    C10+ n-Paraffins',
#  'Feed    C10+ i-Paraffins',
#  'Feed    C10+ Naphthenes',
#  'Feed    C10+ Aromtics',
#  'Product Separator Pressure, kg/cm2_g',
#  'H2/HC Ratio']

# %% [markdown]
# # y_col

# %%
script = '''
y1 = data["Product    Hydrogen"]
y2 = data["Product    Methane"]
y3 = data["Product    Ethane"]
y4 = data["Product    Propane"]
y5 = data["Product    n-Butane"]
y6 = data["Product    i-Butane"]
y7 = data["Product    C4 Naphthenes"]
y8 = data["Product    n-Pentane"]
y9 = data["Product    C5 i-Paraffins"]
y10 = data["Product    C5 Naphthenes"]
y11 = data["Product    n-Hexane"]
y12 = data["Product    C6 i-Paraffins"]
y13 = data["Product    C6 Naphthenes"]
y14 = data["Product    Benzene"]
y15 = data["Product    n-Heptane"]
y16 = data["Product    C7 i-Paraffins"]
y17 = data["Product    C7 Naphthenes"]
y18 = data["Product    Toluene"]
y19 = data["Product    n-Octane"]
y20 = data["Product    C8 i-Paraffins"]
y21 = data["Product    C8 Naphthenes"]
y22 = data["Product    Ethylbenzene"]
y23 = data["Product    P-Xylene"]
y24 = data["Product    M-Xylene"]
y25 = data["Product    O-Xylene"]
y26 = data["Product    n-Nonane"]
y27 = data["Product    C9 i-Paraffins"]
y28 = data["Product    C9 Naphthenes"]
y29 = data["Product    C9 Aromtics"]
y30 = data["Product    C10+ n-Paraffins"]
y31 = data["Product    C10+ i-Paraffins"]
y32 = data["Product    C10+ Naphthenes"]
y33 = data["Product    C10+ Aromtics"]
'''

# %%
y_col = []
for i in script.split('\n'):
    if ('[' in i)&(']'in i)&('Product' in i):
        s = i.index('["')+2
        e = i.index('"]')
        y_col.append(i[s:e])
y_col
# Out:
# ['Product    Hydrogen',
#  'Product    Methane',
#  'Product    Ethane',
#  'Product    Propane',
#  'Product    n-Butane',
#  'Product    i-Butane',
#  'Product    C4 Naphthenes',
#  'Product    n-Pentane',
#  'Product    C5 i-Paraffins',
#  'Product    C5 Naphthenes',
#  'Product    n-Hexane',
#  'Product    C6 i-Paraffins',
#  'Product    C6 Naphthenes',
#  'Product    Benzene',
#  'Product    n-Heptane',
#  'Product    C7 i-Paraffins',
#  'Product    C7 Naphthenes',
#  'Product    Toluene',
#  'Product    n-Octane',
#  'Product    C8 i-Paraffins',
#  'Product    C8 Naphthenes',
#  'Product    Ethylbenzene',
#  'Product    P-Xylene',
#  'Product    M-Xylene',
#  'Product    O-Xylene',
#  'Product    n-Nonane',
#  'Product    C9 i-Paraffins',
#  'Product    C9 Naphthenes',
#  'Product    C9 Aromtics',
#  'Product    C10+ n-Paraffins',
#  'Product    C10+ i-Paraffins',
#  'Product    C10+ Naphthenes',
#  'Product    C10+ Aromtics']

# %% [markdown]
# # 整理

# %%
data = data[x_col+y_col].astype('float32').dropna(axis=0)
data = data.loc[data[(data<0)==False].index]

# %%
testdata = testdata[x_col+y_col].astype('float32').dropna(axis=0)
testdata = testdata.loc[testdata[(testdata<0)==False].index]

# %% [markdown]
# # get  cleaned data

# %%
X_train = data[x_col]
X_test = testdata[x_col]
y_train = data[y_col]
y_test = testdata[y_col]
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((576, 43), (576, 33), (20, 43), (20, 33))

# %%
X_train[X_train>0].shape
# Out:
# (576, 43)

# %% [markdown]
# # group x_col

# %%
sum_col = ['Feed    Methane','Feed    Ethane','Feed    n-Butane',
          'Feed    i-Butane','Feed    C4 Naphthenes','Feed    n-Pentane','Feed    C5 i-Paraffins',
          'Feed    C5 Naphthenes','Feed    C6 i-Paraffins']

# %%
#print(X_train.shape)
#X_train['Feed    C6 i-Paraffins'] = X_train[sum_col].sum(axis=1)
#X_train = X_train.drop(sum_col,axis=1)
#print(X_train.shape)

# %%
#print(X_test.shape)
#X_test['Feed    C6 i-Paraffins'] = X_test[sum_col].sum(axis=1)
#X_test = X_test.drop(sum_col,axis=1)
#print(X_test.shape)

# %%
x_col = X_train.columns.tolist()
print(len(x_col))
# Out:
# 43

# %% [markdown]
# # scale data

# %%
from sklearn.preprocessing import MinMaxScaler

mm_x = MinMaxScaler()
mm_x.fit(X_train.append(X_test))

mm_y = MinMaxScaler()
mm_y.fit(y_train.append(y_test))

X_train[:] = mm_x.transform(X_train[:])
X_test[:] = mm_x.transform(X_test[:])

y_train[:] = mm_y.transform(y_train[:])
y_test[:] = mm_y.transform(y_test[:])

# %%
X_train.shape,y_train.shape,X_test.shape,y_test.shape
# Out:
# ((576, 43), (576, 33), (20, 43), (20, 33))

# %% [markdown]
# # torch data_iter

# %%
X_train = torch.tensor(X_train.values,dtype=torch.float)#.cuda()
X_test = torch.tensor(X_test.values,dtype=torch.float)#.cuda()

y_train = torch.tensor(y_train.values,dtype=torch.float)#.cuda()
y_test = torch.tensor(y_test.values,dtype=torch.float)#.cuda()

datasets = torch.utils.data.TensorDataset(X_train, y_train)
train_iter = torch.utils.data.DataLoader(datasets, batch_size=int(576/4))

# %% [markdown]
# # define model

# %%
class model4333(nn.Module):
    def __init__(self,input_shape,output_shape):
        super(model4333,self).__init__()
        self.fc1 = Linear(input_shape,256,bias=False)
        self.fc2 = Linear(256,128,bias=False)
        self.fc3 = Linear(128,output_shape,bias=False)
        self.dropout = Dropout(0.1)
    
    def forward(self,x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.dropout(x)
        x = F.sigmoid(self.fc3(x))
        return x

# %%
def init_weights(m):
    if hasattr(m,'weight'):
        try:
            torch.nn.init.xavier_uniform(m.weight)
        except:
            pass
    if hasattr(m,'bias'):
        try:
            m.bias.data.fill_(0.01)
        except:
            pass

# %%
net = model4333(len(x_col),len(y_col))#.cuda()
net.apply(init_weights)
# Out:
# model4333(
#   (fc1): Linear(in_features=43, out_features=256, bias=False)
#   (fc2): Linear(in_features=256, out_features=128, bias=False)
#   (fc3): Linear(in_features=128, out_features=33, bias=False)
#   (dropout): Dropout(p=0.1, inplace=False)
# )

# %%
net(X_test[0])
# Out:
# tensor([0.4974, 0.5228, 0.5013, 0.4645, 0.5583, 0.5229, 0.5421, 0.4961, 0.5098,
#         0.4920, 0.4699, 0.4528, 0.5037, 0.4857, 0.4723, 0.5708, 0.4889, 0.4957,
#         0.5146, 0.4436, 0.4778, 0.4130, 0.5500, 0.5388, 0.5166, 0.4856, 0.4643,
#         0.5899, 0.5945, 0.5706, 0.4958, 0.5261, 0.5155],
#        grad_fn=<SigmoidBackward>)

# %% [markdown]
# # loss and opt

# %%
loss_function = nn.MSELoss()
optimizer = optim.Adam(net.parameters(),lr=0.01)

# %%
def train(net,train_iter,valid_iter,loss_function,optimizer,num_epochs=100):
    train_history = []
    valid_history = []
    best_loss = np.inf
    best_net = None
    
    for epoch in range(num_epochs):
        # train
        net.train()
        train_loss = 0
        t = 0
        for x,y in train_iter:
            loss = loss_function(net(x),y)
            
            # weight update
            loss.backward()
            optimizer.step()
            optimizer.zero_grad()
            
            # record loss
            train_loss += loss.item()
            t += 1
        train_history.append(train_loss/t)
        
        # eval
        net.eval()
        valid_loss = 0
        t = 0
        for x,y in valid_iter:
            loss = loss_function(net(x),y)
            # record loss
            valid_loss += loss.item()
            t += 1
        valid_history.append(valid_loss/t)
        
        # print the epoch loss
        print("epochs {} train loss {:.4f} valid loss {:.4f}".format(
            epoch,train_history[-1],valid_history[-1]))
        
        # record best_net
        if valid_history[-1] <= best_loss:
            best_loss = valid_history[-1]
            best_net = net
            print('record net')
    
    # when end all epoch plot history
    plt.plot(np.array(train_history),label='train')
    plt.plot(np.array(valid_history),label='valid')
    plt.title('loss history')
    plt.legend()
    plt.show()
    
    # return best_net
    return best_net

# %%
net = train(net,train_iter,train_iter,loss_function,optimizer,num_epochs=200)
# Out:
# epochs 0 train loss 0.0402 valid loss 0.0230
# record net
# epochs 1 train loss 0.0239 valid loss 0.0205
# record net
# epochs 2 train loss 0.0211 valid loss 0.0182
# record net
# epochs 3 train loss 0.0188 valid loss 0.0170
# record net
# epochs 4 train loss 0.0175 valid loss 0.0158
# record net
# epochs 5 train loss 0.0161 valid loss 0.0144
# record net
# epochs 6 train loss 0.0149 valid loss 0.0135
# record net
# epochs 7 train loss 0.0138 valid loss 0.0123
# record net
# epochs 8 train loss 0.0127 valid loss 0.0115
# record net
# epochs 9 train loss 0.0120 valid loss 0.0111
# record net
# epochs 10 train loss 0.0116 valid loss 0.0108
# record net
# epochs 11 train loss 0.0114 valid loss 0.0105
# record net
# epochs 12 train loss 0.0112 valid loss 0.0102
# record net
# epochs 13 train loss 0.0109 valid loss 0.0102
# record net
# epochs 14 train loss 0.0108 valid loss 0.0099
# record net
# epochs 15 train loss 0.0106 valid loss 0.0097
# record net
# epochs 16 train loss 0.0105 valid loss 0.0098
# epochs 17 train loss 0.0106 valid loss 0.0096
# record net
# epochs 18 train loss 0.0102 valid loss 0.0103
# epochs 19 train loss 0.0109 valid loss 0.0097
# epochs 20 train loss 0.0108 valid loss 0.0111
# epochs 21 train loss 0.0109 valid loss 0.0101
# epochs 22 train loss 0.0106 valid loss 0.0093
# record net
# epochs 23 train loss 0.0098 valid loss 0.0092
# record net
# epochs 24 train loss 0.0097 valid loss 0.0088
# record net
# epochs 25 train loss 0.0094 valid loss 0.0087
# record net
# epochs 26 train loss 0.0094 valid loss 0.0087
# record net
# epochs 27 train loss 0.0094 valid loss 0.0085
# record net
# epochs 194 train loss 0.0051 valid loss 0.0044
# epochs 195 train loss 0.0052 valid loss 0.0046
# epochs 196 train loss 0.0055 valid loss 0.0046
# epochs 197 train loss 0.0057 valid loss 0.0046
# epochs 198 train loss 0.0056 valid loss 0.0047
# epochs 199 train loss 0.0056 valid loss 0.0049

# %% [markdown]
# # make prediction

# %%
y_pred = net(X_test).cpu().detach().numpy()
y_pred = mm_y.inverse_transform(y_pred)
y_pred = pd.DataFrame(y_pred,columns=y_col)
y_pred.head()
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0          2603.374023          788.797424        2291.802002
# 1          2601.248047          787.447083        2284.916260
# 2          2620.830078          772.566772        2234.843262
# 3          2604.875244          788.504456        2279.531250
# 4          2607.044434          794.927917        2263.884033
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         2860.813965          1125.310303          1012.166443
# 1         2877.932129          1117.874512           993.986938
# 2         2839.984131          1111.873291           994.392944
# 3         2897.581055          1103.570923           984.305908
# 4         2882.756104          1098.627197           990.341919
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                  1.003034           1700.704224                2571.366943
# 1                  1.009400           1694.085938                2563.138184
# 2                  0.993417           1641.900757                2489.088867
# 3                  1.028543           1678.905518                2543.332764
# 4                  1.040784           1672.755371                2537.065186
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                 34.507687  ...         10086.990234          5339.043457
# 1                 34.537796  ...         10147.784180          5364.160645
# 2                 36.267002  ...         10177.657227          5405.012695
# 3                 34.921432  ...         10154.552734          5363.288086
# 4                 36.235527  ...         10200.724609          5366.462891
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0             7.423725                  29.575237                 22.077082
# 1             7.484103                  30.015863                 21.376087
# 2             7.580765                  30.226990                 21.480928
# 3             8.017696                  31.704334                 21.271244
# 4             8.571058                  34.982460                 21.136581
#
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0             9255.262695                    98.145905
# 1             9337.194336                    97.340668
# 2             9177.937500                    93.980309
# 3             9381.655273                    97.403755
# 4             9387.158203                    95.413071
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   204.738068                  137.883957
# 1                   202.485275                  136.342041
# 2                   197.879440                  132.369827
# 3                   201.910675                  135.955490
# 4                   197.108597                  132.392975
#
#    Product    C10+ Aromtics
# 0               1860.511597
# 1               1846.390015
# 2               1769.546997
# 3               1855.867188
# 4               1835.615723
#
# [5 rows x 33 columns]

# %%
y_real = y_test.cpu().detach().numpy()
y_real = mm_y.inverse_transform(y_real)
y_real = pd.DataFrame(y_real,columns=y_col)
y_real.head()
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0          2585.543945          783.050415        2167.787842
# 1          2603.471924          802.383057        2194.137207
# 2          2583.133789          875.061646        2180.787842
# 3          2569.629395          888.716797        2207.623291
# 4          2565.668457          887.868958        2179.576416
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         2652.459229          1190.827881          1204.990967
# 1         2121.544434          1468.593384          1563.974609
# 2         2890.277100          1133.259888          1070.766968
# 3         2813.154541          1111.260986          1039.723999
# 4         2809.469727          1067.980591           977.900574
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                  0.993305           1659.135986                2504.534424
# 1                  0.991749           1688.823486                2555.859863
# 2                  1.117023           1658.076660                2512.558594
# 3                  0.992776           1702.433350                2574.746338
# 4                  1.119704           1716.807129                2595.738770
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                 37.759480  ...         10368.238281          5203.674805
# 1                 37.822842  ...         10326.885742          5182.920898
# 2                 37.748611  ...         10314.416992          5176.662598
# 3                 39.185349  ...         10330.271484          5184.620117
# 4                 39.400585  ...         10360.566406          5199.824219
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0             7.924978                  28.818098                 21.613573
# 1             8.026572                  27.728163                 21.890656
# 2             7.963961                  27.511864                 20.995895
# 3             7.294888                  25.532108                 21.155176
# 4             7.954565                  28.925695                 20.971128
#
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0             9198.000977                    89.397423
# 1             9217.684570                    88.513573
# 2             9191.858398                    94.822845
# 3             9204.890625                    87.612442
# 4             9265.552734                    88.705467
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   174.555023                  119.134476
# 1                   172.790543                  118.854874
# 2                   185.389496                  127.154457
# 3                   169.090652                  118.264389
# 4                   173.766342                  119.839462
#
#    Product    C10+ Aromtics
# 0               1788.525391
# 1               1775.654541
# 2               1778.274780
# 3               1773.150635
# 4               1788.048950
#
# [5 rows x 33 columns]

# %% [markdown]
# # metric

# %%
from sklearn.metrics import r2_score,mean_squared_error
def mape(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
res = pd.DataFrame(index=y_col,columns=['R2','MSE','MAPE'])

for i in y_col:
    res.loc[i,'R2'] = r2_score(y_real[i],y_pred[i])
    res.loc[i,'MSE'] = mean_squared_error(y_real[i],y_pred[i])
    res.loc[i,'MAPE'] = mape(y_real[i],y_pred[i])
res.loc['AVG'] = res.mean(axis=0)
res
# Out:
#                                     R2      MSE     MAPE
# Product    Hydrogen           0.106441  2875.06  1.65121
# Product    Methane           -0.480159  14488.9  9.69562
# Product    Ethane             0.459821  8677.69  3.42698
# Product    Propane           -0.824033   147888  12.6932
# Product    n-Butane          -0.178512    18057  7.65322
# Product    i-Butane           -0.61679  50171.9  12.9251
# Product    C4 Naphthenes     0.0378181  0.67558  8.95571
# Product    n-Pentane          0.788292  9308.73  4.17432
# Product    C5 i-Paraffins      0.78705  20095.7   4.0488
# Product    C5 Naphthenes      -2.11653  6.95001  5.82894
# Product    n-Hexane           0.459612  490.872  3.29135
# Product    C6 i-Paraffins     0.423426  2294.31  2.94577
# Product    C6 Naphthenes     -0.151089  408.249  10.6927
# Product    Benzene            0.525313  4604.75  2.67081
# Product    n-Heptane         0.0480097  9153.49  9.18034
# Product    C7 i-Paraffins    0.0377404  99960.8  8.03919
# Product    C7 Naphthenes       0.16389   1963.6  15.9349
# Product    Toluene            0.779518   329870  2.97991
# Product    n-Octane           0.220045  1531.56  21.7586
# Product    C8 i-Paraffins     0.197947  15029.6  18.2345
# Product    C8 Naphthenes    -0.0980235  1519.47  22.5263
# Product    Ethylbenzene       -3.10996    50197  6.08038
# Product    P-Xylene           -9.75787  93317.8  10.4022
# Product    M-Xylene           0.688457    33507  1.67065
# Product    O-Xylene          -0.564288  42378.4  3.80963
# Product    n-Nonane           0.215486   17.911  20.5785
# Product    C9 i-Paraffins     0.170714  471.436  28.9192
# Product    C9 Naphthenes     -0.710993  6.27622  7.03015
# Product    C9 Aromtics        0.846958  67662.3  1.88449
# Product    C10+ n-Paraffins   0.176438  188.435  10.3818
# Product    C10+ i-Paraffins  -0.029267  863.037  12.7657
# Product    C10+ Naphthenes    0.118022  376.916  11.6753
# Product    C10+ Aromtics      0.763226    10198  4.28573
# AVG                          -0.321918  31441.9  9.35731

# %% [markdown]
# # wraper model

# %%
class model_4333_wraper:
    def __init__(self):
        self.x_col = x_col
        self.y_col = y_col
        self.mm_x = mm_x
        self.mm_y = mm_y
        self.net = net.eval()
    
    def predict(self,x):
        feed = x.iloc[:,8:8+33].sum(axis=1).values.reshape(-1,1)
        x = self.mm_x.transform(x)
        x = torch.tensor(x,dtype=torch.float)#.cuda()
        y = self.net(x)
        y = y.detach().cpu().numpy()
        y = self.mm_y.inverse_transform(y)
        y = self.normalize(y,feed)
        y = pd.DataFrame(y,columns=self.y_col)
        print(y)
        output = y.sum(axis=1).values.reshape(-1,1)
        assert np.allclose(feed,output)
        assert np.all(y.values >= 0)
        return y
    
    def normalize(self,x,feed):
        x = x / x.sum(axis=1).reshape(-1,1)
        x *= feed
        return x

# %%
model = model_4333_wraper()

# %%
X_test = pd.DataFrame(X_test.detach().cpu().numpy(),columns=x_col)

# %%
X_test[:] = mm_x.inverse_transform(X_test)

# %%
X_test.head()
# Out:
#        N+2A in Naphtha Feed, wt%      Chlorine in Fresh Catalyst, wt%  \
# 0                      62.388248                             0.944780
# 1                      63.119473                             0.931290
# 2                      63.259529                             0.928645
# 3                      62.810543                             0.913635
# 4                      62.596928                             0.913195
#
#    Carbon in Spent Catalyst, %      C6P- in Naphtha Feed, wt%  \
# 0                       3.8015                       0.519984
# 1                       3.8320                       0.528968
# 2                       3.7630                       0.551923
# 3                       3.8590                       0.522963
# 4                       3.7770                       0.544962
#
#        3R211 Inlet Tem, oC      3R212 Inlet Temp, oC  \
# 0               525.010925                525.000854
# 1               525.005981                525.009521
# 2               525.004639                525.001404
# 3               524.466248                525.006897
# 4               523.334412                524.333679
#
#        3R213 Inlet Temp, oC      3R214 Inlet Temp, oC  Feed    Hydrogen  \
# 0                525.017944                516.013000               0.0
# 1                524.994446                516.015686               0.0
# 2                525.011169                516.004089               0.0
# 3                524.990601                516.009033               0.0
# 4                524.334839                515.984741               0.0
#
#    Feed    Methane  ...  Feed    n-Nonane  Feed    C9 i-Paraffins  \
# 0              0.0  ...       3517.725830             6404.042480
# 1              0.0  ...       3637.014160             6542.346680
# 2              0.0  ...       3486.991699             5947.743164
# 3              0.0  ...       3636.807373             6497.169434
# 4              0.0  ...       3628.716553             6481.561035
#
#    Feed    C9 Naphthenes  Feed    C9 Aromtics  Feed    C10+ n-Paraffins  \
# 0            2514.497070          1798.867554                357.764374
# 1            2597.256104          1848.255615                362.016083
# 2            2616.527588          1728.325195                342.066620
# 3            2681.643066          1831.335693                366.754639
# 4            2682.615234          1819.025757                365.363129
#
#    Feed    C10+ i-Paraffins  Feed    C10+ Naphthenes  Feed    C10+ Aromtics  \
# 0               1413.709961               137.142532             124.334557
# 1               1410.414307               129.325073             110.656944
# 2               1336.967285               122.385391             109.738213
# 3               1421.607544               134.156174             112.465012
# 4               1411.612793               130.418716             107.192924
#
#    Product Separator Pressure, kg/cm2_g  H2/HC Ratio
# 0                              4.700871     1.442642
# 1                              4.696388     1.474911
# 2                              4.700059     1.495016
# 3                              4.700067     1.475583
# 4                              4.695580     1.498736
#
# [5 rows x 43 columns]

# %%
y_test = pd.DataFrame(y_test.detach().cpu().numpy(),columns=y_col)

# %%
y_test[:] = mm_y.inverse_transform(y_test)

# %%
y_test.head()
# Out:
#    Product    Hydrogen  Product    Methane  Product    Ethane  \
# 0          2585.543945          783.050415        2167.787842
# 1          2603.471924          802.383057        2194.137207
# 2          2583.133789          875.061646        2180.787842
# 3          2569.629395          888.716797        2207.623291
# 4          2565.668457          887.868958        2179.576416
#
#    Product    Propane  Product    n-Butane  Product    i-Butane  \
# 0         2652.459229          1190.827881          1204.990967
# 1         2121.544434          1468.593384          1563.974609
# 2         2890.277100          1133.259888          1070.766968
# 3         2813.154541          1111.260986          1039.723999
# 4         2809.469727          1067.980591           977.900574
#
#    Product    C4 Naphthenes  Product    n-Pentane  Product    C5 i-Paraffins  \
# 0                  0.993305           1659.135986                2504.534424
# 1                  0.991749           1688.823486                2555.859863
# 2                  1.117023           1658.076660                2512.558594
# 3                  0.992776           1702.433350                2574.746338
# 4                  1.119704           1716.807129                2595.738770
#
#    Product    C5 Naphthenes  ...  Product    M-Xylene  Product    O-Xylene  \
# 0                 37.759480  ...         10368.238281          5203.674805
# 1                 37.822842  ...         10326.885742          5182.920898
# 2                 37.748611  ...         10314.416992          5176.662598
# 3                 39.185349  ...         10330.271484          5184.620117
# 4                 39.400585  ...         10360.566406          5199.824219
#
#    Product    n-Nonane  Product    C9 i-Paraffins  Product    C9 Naphthenes  \
# 0             7.924978                  28.818098                 21.613573
# 1             8.026572                  27.728163                 21.890656
# 2             7.963961                  27.511864                 20.995895
#    Product    C9 Aromtics  Product    C10+ n-Paraffins  \
# 0             9265.152344                    98.250778
# 1             9355.841797                    97.535072
# 2             9196.235352                    94.167679
# 3             9391.718750                    97.508240
# 4             9397.126953                    95.514389
#
#    Product    C10+ i-Paraffins  Product    C10+ Naphthenes  \
# 0                   204.956848                  138.031296
# 1                   202.889664                  136.614334
# 2                   198.273972                  132.633728
# 3                   202.127258                  136.101318
# 4                   197.317917                  132.533569
#
#    Product    C10+ Aromtics
# 0               1862.499634
# 1               1850.077637
# 2               1773.074951
# 3               1857.857910
# 4               1837.565063
#
# [5 rows x 33 columns]

# %%
y_real = y_test

# %%
res = pd.DataFrame(index=y_col,columns=['R2','MSE','MAPE'])

for i in y_col:
    res.loc[i,'R2'] = r2_score(y_real[i],y_pred[i])
    res.loc[i,'MSE'] = mean_squared_error(y_real[i],y_pred[i])
    res.loc[i,'MAPE'] = mape(y_real[i],y_pred[i])
res.loc['AVG'] = res.mean(axis=0)
res
# Out:
#                                     R2       MSE     MAPE
# Product    Hydrogen           0.191767   2600.52  1.52298
# Product    Methane            -0.45791   14271.1  9.45624
# Product    Ethane             0.491349    8171.2  3.28529
# Product    Propane           -0.777678    144129   12.451
# Product    n-Butane          -0.195473   18316.9  7.76443
# Product    i-Butane          -0.632176   50649.4  13.0621
# Product    C4 Naphthenes     0.0381934  0.675316  8.85549
# Product    n-Pentane          0.790151   9227.01  4.12973
# Product    C5 i-Paraffins     0.789437   19870.5  4.00459
# Product    C5 Naphthenes      -2.15863   7.04389  5.82948
# Product    n-Hexane           0.472706   478.978  3.16357
# Product    C6 i-Paraffins      0.42135   2302.57   2.9878
# Product    C6 Naphthenes     -0.161411   411.909  10.6265
# Product    Benzene            0.515645   4698.54  2.74487
# Product    n-Heptane         0.0533186   9102.45  9.13038
# Product    C7 i-Paraffins    0.0417659   99542.6  8.00317
# Product    C7 Naphthenes      0.162089   1967.83  15.8383
# Product    Toluene            0.763047    354512  3.11339
# Product    n-Octane           0.220408   1530.84  21.6482
# Product    C8 i-Paraffins     0.196093   15064.3  18.1719
# Product    C8 Naphthenes    -0.0987512   1520.48  22.4334
# Product    Ethylbenzene       -2.86832   47245.7  5.87223
# Product    P-Xylene           -10.1278   96526.8  10.5741
# Product    M-Xylene           0.748533   27045.6  1.48704
# Product    O-Xylene          -0.418255   38422.2  3.60612
# Product    n-Nonane           0.212593    17.977  20.4788
# Product    C9 i-Paraffins     0.168365   472.771  28.8647
# Product    C9 Naphthenes     -0.768306   6.48645   7.1772
# Product    C9 Aromtics        0.850933   65904.9  1.82599
# Product    C10+ n-Paraffins   0.169437   190.037  10.3193
# Product    C10+ i-Paraffins -0.0352253   868.033  12.7237
# Product    C10+ Naphthenes    0.110756   380.021  11.6334
# Product    C10+ Aromtics        0.7676   10009.6  4.22835
# AVG                          -0.318921   31680.8  9.30345

# %%
import joblib
joblib.dump(model,'../model/transformer(43_to_33).pkl')
# Out:
# ['../model/transformer(43_to_33).pkl']
